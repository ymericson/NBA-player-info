# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
from bs4 import BeautifulSoup, SoupStrainer
import sys, string, requests, datetime, time
# %matplotlib inline

# %%
players_merged_df = pd.read_csv('Tables/players_merged_df.csv')

# %%
players_merged_df.head()
# Out:
#                   name  active_from  active_to  birth_date        position  \
# 0       Alaa Abdelnaby         1991       1995  1968-06-24   Power Forward
# 1      Zaid Abdul-Aziz         1969       1978  1946-04-07          Center
# 2  Kareem Abdul-Jabbar         1970       1989  1947-04-16          Center
# 3   Mahmoud Abdul-Rauf         1991       2001  1969-03-09     Point Guard
# 4    Tariq Abdul-Wahad         1998       2003  1974-11-03  Shooting Guard
#
#   trad_position   ppg   trb  ast  height_inches  weight shooting_hand  \
# 0       Forward   5.7   3.3  0.3           82.0   240.0         Right
# 1        Center   9.0   8.0  1.2           81.0   235.0         Right
# 2        Center  24.6  11.2  3.6           86.0   225.0         Right
# 3         Guard  14.6   1.9  3.5           73.0   162.0         Right
# 4         Guard   7.8   3.3  1.1           78.0   223.0         Right
#
#                                              college                 hs_name  \
# 0                                    Duke University             Bloomfield
# 1                              Iowa State University               John Jay
# 2              University of California, Los Angeles         Power Memorial
# 3                         Louisiana State University               Gulfport
# 4  University of Michigan, San Jose State University  Lycee Aristide Briand
#
#       hs_city     hs_state                        url
# 0  Bloomfield   New Jersey  /players/a/abdelal01.html
# 1    Brooklyn     New York  /players/a/abdulza01.html
# 2    New York     New York  /players/a/abdulka01.html
# 3    Gulfport  Mississippi  /players/a/abdulma02.html
# 4      Evreux       France  /players/a/abdulta01.html

# %% [markdown]
# ## Data visualization

# %% [markdown]
# ### Individual statistics

# %%
plt.figure(figsize=(10,8))

ax = sns.regplot(x='weight', y='height_inches', data=players_merged_df, 
                 color='grey', fit_reg=False, scatter_kws={"s": 20})

ax.set(xlabel='Weight in Pounds', ylabel='Height in Inches')
plt.show()

# %%
ax = sns.lmplot(x="weight", y="height_inches", data=players_merged_df, 
               col='trad_position', hue='trad_position',
               x_jitter=.1, fit_reg=False, scatter_kws={"s": 10})

ax.set(xlabel='Weight in Pounds', ylabel='Height in Inches')

# %%
ax = sns.lmplot(x="weight", y="height_inches", data=players_merged_df, 
               col='position', hue='position',
               x_jitter=.1, fit_reg=False, scatter_kws={"s": 21})

ax.set(xlabel='Weight in Pounds', ylabel='Height in Inches')

# %%
top_colleges = players_merged_df['college'].value_counts()[:20]
top_colleges_df = pd.DataFrame(top_colleges)
top_colleges_df.columns = ['Count']

plt.figure(figsize=(16,12))
sns.barplot(x='Count', y=top_colleges_df.index, data=top_colleges_df, palette="Blues_d")
plt.title('Number of NBA Players by College', fontsize=20)
plt.ylabel('College', fontsize=15)
plt.gca().set_yticks([]);

for num in range(len(top_colleges)):
    plt.text(top_colleges[num]-4, num, top_colleges[num], color='white', size=13, verticalalignment='center')
    plt.text(1, num, top_colleges.index[num], color='white', size=13, verticalalignment='center')

# %%
players_feat = players_merged_df[['position', 'trad_position', 'ppg', 'trb', 'ast', 'height_inches', 'weight']].copy()

players_feat['pos_num'] = players_feat['position'].map({'Point Guard': 1,
                                                       'Shooting Guard': 2,
                                                       'Small Forward': 3,
                                                       'Power Forward': 4,
                                                       'Center': 5})
players_feat.head(10)
# Out:
#          position trad_position   ppg   trb  ast  height_inches  weight  \
# 0   Power Forward       Forward   5.7   3.3  0.3           82.0   240.0
# 1          Center        Center   9.0   8.0  1.2           81.0   235.0
# 2          Center        Center  24.6  11.2  3.6           86.0   225.0
# 3     Point Guard         Guard  14.6   1.9  3.5           73.0   162.0
# 4  Shooting Guard         Guard   7.8   3.3  1.1           78.0   223.0
# 5   Small Forward       Forward  18.1   7.5  2.5           81.0   225.0
# 6   Power Forward       Forward   5.6   3.2  1.2           79.0   220.0
# 7     Point Guard         Guard   0.0   1.0  1.0           75.0   180.0
# 8             NaN           NaN   NaN   NaN  NaN           75.0   195.0
# 9  Shooting Guard         Guard   5.3   1.4  0.5           78.0   190.0
#
#    pos_num
# 0      4.0
# 1      5.0
# 2      5.0
# 3      1.0
# 4      2.0
# 5      3.0
# 6      4.0
# 7      1.0
# 8      NaN
# 9      2.0

# %%
sns.heatmap(players_feat.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
players_feat = players_feat.dropna()
sns.heatmap(players_feat.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
players_feat.head()
# Out:
#          position trad_position   ppg   trb  ast  height_inches  weight  \
# 0   Power Forward       Forward   5.7   3.3  0.3           82.0   240.0
# 1          Center        Center   9.0   8.0  1.2           81.0   235.0
# 2          Center        Center  24.6  11.2  3.6           86.0   225.0
# 3     Point Guard         Guard  14.6   1.9  3.5           73.0   162.0
# 4  Shooting Guard         Guard   7.8   3.3  1.1           78.0   223.0
#
#    pos_num
# 0      4.0
# 1      5.0
# 2      5.0
# 3      1.0
# 4      2.0

# %%
players_feat.groupby('position').count()['trad_position'].plot.bar(figsize=(10,7))

# %% [markdown]
# ### Model data for Machine Learning regression

# %%
from sklearn.model_selection import train_test_split
X = players_feat[['ppg', 'trb', 'ast', 'height_inches', 'weight']]
y = players_feat['pos_num']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.svm import SVR

svr = SVR()
svr.fit(X_train, y_train)

# print(svr.score(X_train, y_train))
print(svr.score(X_test, y_test))
# Out:
# 0.6923256485051702

# %%
from sklearn.linear_model import LinearRegression

lm = LinearRegression()
lm.fit(X_train, y_train)

# print(lm.score(X_train, y_train))
print(lm.score(X_test, y_test))
# Out:
# 0.7943889254433173

# %%
from sklearn.model_selection import train_test_split
X = players_feat[['ppg', 'trb', 'ast', 'height_inches', 'weight']]
y = players_feat['position']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

logmodel = LogisticRegression()
logmodel.fit(X_train, y_train)
predictions = logmodel.predict(X_test)

print(classification_report(y_test, predictions))
print('\n')
print(confusion_matrix(y_test, predictions))
# Out:
#                 precision    recall  f1-score   support
#
#         Center       0.55      0.80      0.65       221
#    Point Guard       0.70      0.78      0.73       241
#  Power Forward       0.50      0.14      0.22       249
# Shooting Guard       0.60      0.56      0.58       296
#  Small Forward       0.47      0.59      0.52       279
#
#    avg / total       0.56      0.57      0.54      1286
#
#
#
# [[176   0  10   2  33]
#  [  0 187   0  43  11]
#  [111   0  36   5  97]
#  [  1  76   6 166  47]
#  [ 30   6  20  59 164]]

# %%
from sklearn.tree import DecisionTreeClassifier

dtree = DecisionTreeClassifier()
dtree.fit(X_train, y_train)
predictions = dtree.predict(X_test)

print(classification_report(y_test, predictions))
print('\n')
print(confusion_matrix(y_test, predictions))
# Out:
#                 precision    recall  f1-score   support
#
#         Center       0.65      0.68      0.67       237
#    Point Guard       0.66      0.65      0.65       236
#  Power Forward       0.46      0.42      0.44       244
# Shooting Guard       0.50      0.47      0.48       292
#  Small Forward       0.46      0.51      0.49       277
#
#    avg / total       0.54      0.54      0.54      1286
#
#
#
# [[162   0  64   0  11]
#  [  0 154   0  77   5]
#  [ 70   0 103   1  70]
#  [  2  73   1 136  80]
#  [ 16   8  54  57 142]]

# %%
from sklearn.tree import DecisionTreeClassifier

dtree = DecisionTreeClassifier()
dtree.fit(X_train, y_train)
predictions = dtree.predict(X_test)

print(classification_report(y_test, predictions))
print('\n')
print(confusion_matrix(y_test, predictions))
# Out:
#                 precision    recall  f1-score   support
#
#         Center       0.66      0.67      0.67       237
#    Point Guard       0.67      0.65      0.66       236
#  Power Forward       0.47      0.45      0.46       244
# Shooting Guard       0.51      0.49      0.50       292
#  Small Forward       0.48      0.52      0.50       277
#
#    avg / total       0.55      0.55      0.55      1286
#
#
#
# [[159   0  66   0  12]
#  [  1 154   1  74   6]
#  [ 68   0 109   5  62]
#  [  1  71   1 143  76]
#  [ 12   6  54  60 145]]

# %% [markdown]
# ### Year-by-year statistics

# %%
left = []
right = []
height = []
weight = []
ppg = []
trb = []
ast = []

start = players_merged_df.active_from.min()
end = players_merged_df.active_from.max()

for year in range(start,end):
    active = (players_merged_df.active_from.values <= year) & (players_merged_df.active_to >= year) # only include active players
    height.append(np.mean(players_merged_df[active].height_inches)) # average height in inches
    weight.append(np.mean(players_merged_df[active].weight)) # average weight in pounds
    left.append(1.0*np.sum(players_merged_df[active].shooting_hand == 'Left')) # number of left handed shooters
    right.append(1.0*np.sum(players_merged_df[active].shooting_hand == 'Right')) # number of right handed shooters
    ppg.append(np.mean(players_merged_df[active].ppg))
    trb.append(np.mean(players_merged_df[active].trb))
    ast.append(np.mean(players_merged_df[active].ast))
    
# create a DataFrame with a summary
stats_year = pd.DataFrame({'season': np.arange(start,end), 
                          'height': height,
                          'weight': weight,
                          'left': left,
                          'right': right,
                          'ppg': ppg,
                          'trb': trb,
                          'ast': ast}).set_index('season')

# preview
stats_year.head()
# Out:
#              ast     height  left       ppg  right       trb      weight
# season
# 1947    1.721739  74.322981   1.0  9.339130   22.0  3.791304  188.656250
# 1948    1.925000  74.570175   1.0  8.993750   31.0  3.671875  187.362832
# 1949    1.944444  75.197740   3.0  8.674603   60.0  3.974603  191.536723
# 1950    2.021138  75.324444   5.0  8.518699  118.0  4.040650  191.493274
# 1951    1.930065  75.843137   6.0  8.183660  147.0  3.984314  194.549020

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, sharex=True, figsize=(12,10))





plt.subplot(2, 1, 1)
plt.title('Height and Weight of NBA Players by Year', fontsize = 20)

plt.plot(stats_year['height'])
plt.ylabel('Height in Inches', fontsize=15)


plt.subplot(2, 1, 2)
plt.plot(stats_year['weight'])
plt.ylabel('Weight in pounds', fontsize=15)
plt.xlabel('Year', fontsize=15)

plt.tight_layout()
plt.show()
